# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\My Files\FreeLancing\Sunil\Software Defect Prediction_2023\Eclipse Datasets/Eclipsedata1.csv")
data.shape
# Out:
# (6729, 200)

# %%
for i in data.columns:
 data[i]=data[i].astype(int)
data
# Out:
#       pre  ACD  FOUT_avg  FOUT_max  FOUT_sum  MLOC_avg  MLOC_max  MLOC_sum  \
# 0       1    0         6        29        54         9        32        74
# 1       1    0        12        13        25        16        18        32
# 2       0    0         5        10        16        12        29        38
# 3       2    0         7        16        88         9        28       116
# 4       2    4         6        27       118         9        55       188
# ...   ...  ...       ...       ...       ...       ...       ...       ...
# 6724    0    0         5        14        15        14        30        43
# 6725    1    0         2         5         5         5         9        11
# 6726    0    0         3         7        21         4         7        29
# 6727    0    0         4        16       103         9        27       203
# 6728    0    0         1         2        14         7        10        71
#
# ...

# %%
correlation_matrix = data.corr()

# %%
plt.figure(figsize=(10, 8))  # Set the figure size as per your preference
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Heat Map of Eclipse 2 Dataset')
plt.show()

# %%
zero_cols = (data == 0).all()

# %%
data = data.loc[:, ~zero_cols]
data
# Out:
#       pre  ACD  FOUT_avg  FOUT_max  FOUT_sum  MLOC_avg  MLOC_max  MLOC_sum  \
# 0       1    0         6        29        54         9        32        74
# 1       1    0        12        13        25        16        18        32
# 2       0    0         5        10        16        12        29        38
# 3       2    0         7        16        88         9        28       116
# 4       2    4         6        27       118         9        55       188
# ...   ...  ...       ...       ...       ...       ...       ...       ...
# 6724    0    0         5        14        15        14        30        43
# 6725    1    0         2         5         5         5         9        11
# 6726    0    0         3         7        21         4         7        29
# 6727    0    0         4        16       103         9        27       203
# 6728    0    0         1         2        14         7        10        71
#
# ...

# %%
data = data.loc[:, ~zero_cols]
data
# Out:
#       pre  ACD  FOUT_avg  FOUT_max  FOUT_sum  MLOC_avg  MLOC_max  MLOC_sum  \
# 0       1    0         6        29        54         9        32        74
# 1       1    0        12        13        25        16        18        32
# 2       0    0         5        10        16        12        29        38
# 3       2    0         7        16        88         9        28       116
# 4       2    4         6        27       118         9        55       188
# ...   ...  ...       ...       ...       ...       ...       ...       ...
# 6724    0    0         5        14        15        14        30        43
# 6725    1    0         2         5         5         5         9        11
# 6726    0    0         3         7        21         4         7        29
# 6727    0    0         4        16       103         9        27       203
# 6728    0    0         1         2        14         7        10        71
#
# ...

# %%
corr=data.corr()
corr
# Out:
#                            pre       ACD  FOUT_avg  FOUT_max  FOUT_sum  \
# pre                   1.000000  0.360430  0.274687  0.407330  0.471807
# ACD                   0.360430  1.000000  0.320713  0.443755  0.438841
# FOUT_avg              0.274687  0.320713  1.000000  0.744481  0.495558
# FOUT_max              0.407330  0.443755  0.744481  1.000000  0.698143
# FOUT_sum              0.471807  0.438841  0.495558  0.698143  1.000000
# ...                        ...       ...       ...       ...       ...
# WhileStatement        0.250002  0.125348  0.182384  0.322650  0.472348
# InstanceofExpression  0.325988  0.269866  0.195501  0.310556  0.380633
# Modifier              0.153219  0.097331  0.040545  0.111295  0.188929
# SUM                   0.438837  0.374507  0.387679  0.617531  0.864129
# post                  0.443016  0.119252  0.175573  0.284341  0.419170
#
#                       MLOC_avg  MLOC_max  MLOC_sum   NBD_avg   NBD_max  ...  \
# ...

# %%
f,ax=plt.subplots(figsize=(10,8))
cmap=sns.diverging_palette(220,10,as_cmap=True)
heatmap=sns.heatmap(corr,cmap=cmap,center=0.0,vmax=1,linewidths=1,ax=ax)
plt.show()
plt.savefig('heatmap.png')
